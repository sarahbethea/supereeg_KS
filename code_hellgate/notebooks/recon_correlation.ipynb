# %%
import numpy as np
import matplotlib.pyplot as plt
import supereeg as se
import glob
import os
# %matplotlib
import plot_electrode_density as ped
import plot
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
def get_corr(results_path):
    within_files = glob.glob(os.path.join(results_path, "*within*"))
    all_files = glob.glob(os.path.join(results_path, "*"))
    across_files = [f for f in all_files if "within" not in os.path.basename(f)]

    within_data = np.zeros(len(within_files))
    within_locs = np.zeros((len(within_files),3))
    for i in range(len(within_files)):
        load = np.load(within_files[i])
        if len(load["corrs"]) == 1:
            within_data[i] = load["corrs"].item()
            within_locs[i] = load["coord"]
    

    within_mean = np.mean(within_data)
    within_median = np.median(within_data)
    within_std = np.std(within_data)
    within_var = np.var(within_data)


    across_data = np.zeros(len(across_files))
    across_locs = np.zeros((len(across_files),3))
    for i in range(len(across_files)):
        load = np.load(across_files[i])
        if len(load["corrs"]) == 1:
            across_data[i] = load["corrs"].item()
            across_locs[i] = load["coord"] 

    across_mean = np.mean(across_data)
    across_median = np.median(across_data)
    across_std = np.std(across_data)
    across_var = np.var(across_data)

    data_corr = {"within_corr": within_data, "within_locs":within_locs ,"across_corr":across_data, "across_locs":across_locs}
    data_stats = {"within_mean":within_mean,"within_median":within_median,"within_std":within_std,"within_var":within_var,
                  "across_mean":across_mean,"across_median":across_median,"across_std":across_std,"across_var":across_var}
    
    return data_corr, data_stats

# %%
data_1, stats_1 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_1_2/recon/results/raw_recon")

data_2, stats_2 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_2_2/recon/results/raw_recon")

data_3, stats_3 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_3_3/recon/results/raw_recon")

data_4, stats_4 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_4_2/recon/results/raw_recon")

data_5, stats_5 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_5_3/recon/results/raw_recon")

data_10, stats_10 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_10_3/recon/results/raw_recon")

data_20, stats_20 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_20_test/recon/results/raw_recon")

data_30, stats_30 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_30_test/recon/results/raw_recon")

data_40, stats_40 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_40_test/recon/results/raw_recon")

data_50, stats_50 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_50_test/recon/results/raw_recon")

# %%
data_1, stats_1 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_1_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_1["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_1["within_mean"]:.3f}, σ = {stats_1["within_std"]:.3f}, σ² = {stats_1["within_var"]:.3f})")
ax.axvline(stats_1["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_1["across_corr"],bins=200,density=True,color="black",alpha=0.7,label=f"Within (μ = {stats_1["across_mean"]:.3f}, σ = {stats_1["across_std"]:.3f}, σ² = {stats_1["across_var"]:.3f})")
ax.axvline(stats_1["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 1)")
ax.legend()
ax.grid()

# %%
data_2, stats_2 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_2_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_2["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_2["within_mean"]:.3f}, σ = {stats_2["within_std"]:.3f}, σ² = {stats_2["within_var"]:.3f})")
ax.axvline(stats_2["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_2["across_corr"],bins=200,density=True,color="black",alpha=0.7,label=f"Within (μ = {stats_2["across_mean"]:.3f}, σ = {stats_2["across_std"]:.3f}, σ² = {stats_2["across_var"]:.3f})")
ax.axvline(stats_2["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 2)")
ax.legend()
ax.grid()

# %%
data_3, stats_3 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_3_1/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_3["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_3["within_mean"]:.3f}, σ = {stats_3["within_std"]:.3f}, σ² = {stats_3["within_var"]:.3f})")
ax.axvline(stats_3["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_3["across_corr"],bins=200,density=True,color="black",alpha=0.7,label=f"Within (μ = {stats_3["across_mean"]:.3f}, σ = {stats_3["across_std"]:.3f}, σ² = {stats_3["across_var"]:.3f})")
ax.axvline(stats_3["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 3)")
ax.legend()
ax.grid()

# %%
data_4, stats_4 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_4_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_4["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_4["within_mean"]:.3f}, σ = {stats_4["within_std"]:.3f}, σ² = {stats_4["within_var"]:.3f})")
ax.axvline(stats_4["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_4["across_corr"],bins=200,density=True,color="black",alpha=0.7,label=f"Within (μ = {stats_4["across_mean"]:.3f}, σ = {stats_4["across_std"]:.3f}, σ² = {stats_4["across_var"]:.3f})")
ax.axvline(stats_4["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 4)")
ax.legend()
ax.grid()

# %%
data_5, stats_5 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_5_3/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_5["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_5["within_mean"]:.3f}, σ = {stats_5["within_std"]:.3f}, σ² = {stats_5["within_var"]:.3f})")
ax.axvline(stats_5["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_5["across_corr"], density= True,bins=200,color="black",alpha=0.7,label=f"Across (μ = {stats_5["across_mean"]:.3f}, σ = {stats_5["across_std"]:.3f}, σ² = {stats_5["across_var"]:.3f})")
ax.axvline(stats_5["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 5)")
ax.legend()
ax.grid()

# %%
data_10, stats_10 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_10_test/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_10["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_10["within_mean"]:.3f}, σ = {stats_10["within_std"]:.3f}, σ² = {stats_10["within_var"]:.3f})")
ax.axvline(stats_10["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_10["across_corr"], density= True,bins=200,color="black",alpha=0.7,label=f"Across (μ = {stats_10["across_mean"]:.3f}, σ = {stats_10["across_std"]:.3f}, σ² = {stats_10["across_var"]:.3f})")
ax.axvline(stats_10["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 10)")
ax.legend()
ax.grid()

# %%
data_20, stats_20 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_20_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_20["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_20["within_mean"]:.3f}, σ = {stats_20["within_std"]:.3f}, σ² = {stats_20["within_var"]:.3f})")
ax.axvline(stats_20["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_20["across_corr"], density= True,bins=200,color="black",alpha=0.7,label=f"Across (μ = {stats_20["across_mean"]:.3f}, σ = {stats_20["across_std"]:.3f}, σ² = {stats_20["across_var"]:.3f})")
ax.axvline(stats_20["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 20)")
ax.legend()
ax.grid()

# %%
data_30, stats_30 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_30_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_30["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_30["within_mean"]:.3f}, σ = {stats_30["within_std"]:.3f}, σ² = {stats_30["within_var"]:.3f})")
ax.axvline(stats_30["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_30["across_corr"], density= True,bins=200,color="black",alpha=0.7,label=f"Across (μ = {stats_30["across_mean"]:.3f}, σ = {stats_30["across_std"]:.3f}, σ² = {stats_30["across_var"]:.3f})")
ax.axvline(stats_30["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 30)")
ax.legend()
ax.grid()

# %%
data_40, stats_40 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_40_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_40["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_40["within_mean"]:.3f}, σ = {stats_40["within_std"]:.3f}, σ² = {stats_40["within_var"]:.3f})")
ax.axvline(stats_40["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_40["across_corr"], density= True,bins=200,color="black",alpha=0.7,label=f"Across (μ = {stats_40["across_mean"]:.3f}, σ = {stats_40["across_std"]:.3f}, σ² = {stats_40["across_var"]:.3f})")
ax.axvline(stats_40["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 40)")
ax.legend()
ax.grid()

# %%
data_50, stats_50 = get_corr("/mnt/beegfs/projects/jc158347/supereeg_jcs/supereeg_env_50_2/recon/results/raw_recon")

fig, ax = plt.subplots(1,figsize=(10,6))

ax.hist(data_50["within_corr"],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {stats_50["within_mean"]:.3f}, σ = {stats_50["within_std"]:.3f}, σ² = {stats_50["within_var"]:.3f})")
ax.axvline(stats_50["within_mean"], color="grey", linestyle="--", linewidth=2)
#ax.plot(x_within,pdf_within,color="grey")
ax.hist(data_50["across_corr"], density= True,bins=200,color="black",alpha=0.7,label=f"Across (μ = {stats_50["across_mean"]:.3f}, σ = {stats_50["across_std"]:.3f}, σ² = {stats_50["across_var"]:.3f})")
ax.axvline(stats_50["across_mean"], color="black", linestyle="--", linewidth=2)
#ax.plot(x_across,pdf_across,color="black")

ax.set_xlabel("Correlation")
ax.set_ylabel("Electrode Density")
ax.set_title("Electrode Reconstruction Correlation(Lambda = 50)")
ax.legend()
ax.grid()

# %%
means_within = [stats_1["within_mean"],stats_2["within_mean"],stats_3["within_mean"],stats_4["within_mean"],stats_5["within_mean"],stats_10["within_mean"],
                     stats_20["within_mean"],stats_30["within_mean"],stats_40["within_mean"],stats_50["within_mean"]]
means_across = [stats_1["across_mean"],stats_2["across_mean"],stats_3["across_mean"],stats_4["across_mean"],stats_5["across_mean"],stats_10["across_mean"],
                     stats_20["across_mean"],stats_30["across_mean"],stats_40["across_mean"],stats_50["across_mean"]]

median_within = [stats_1["within_median"],stats_2["within_median"],stats_3["within_median"],stats_4["within_median"],stats_5["within_median"],stats_10["within_median"],
                     stats_20["within_median"],stats_30["within_median"],stats_40["within_median"],stats_50["within_median"]]
median_across = [stats_1["across_median"],stats_2["across_median"],stats_3["across_median"],stats_4["across_median"],stats_5["across_median"],stats_10["across_median"],
                     stats_20["across_median"],stats_30["across_median"],stats_40["across_median"],stats_50["across_median"]]

std_within = [stats_1["within_std"],stats_2["within_std"],stats_3["within_std"],stats_4["within_std"],stats_5["within_std"],stats_10["within_std"],
                   stats_20["within_std"],stats_30["within_std"],stats_40["within_std"],stats_50["within_std"]]
std_across = [stats_1["across_std"],stats_2["across_std"],stats_3["across_std"],stats_4["across_std"],stats_5["across_std"],stats_10["across_std"],
                   stats_20["across_std"],stats_30["across_std"],stats_40["across_std"],stats_50["across_std"]]

var_within = [stats_1["within_var"],stats_2["within_var"],stats_3["within_var"],stats_4["within_var"],stats_5["within_var"],stats_10["within_var"],
              stats_20["within_var"],stats_30["within_var"],stats_40["within_var"],stats_50["within_var"]]
var_across = [stats_1["across_var"],stats_2["across_var"],stats_3["across_var"],stats_4["across_var"],stats_5["across_var"],stats_10["across_var"],
              stats_20["across_var"],stats_30["across_var"],stats_40["across_var"],stats_50["across_var"]]

# %%
all_data_across = [data_1["across_corr"],data_2["across_corr"],data_3["across_corr"],data_4["across_corr"],data_5["across_corr"],data_10["across_corr"],
                   data_20["across_corr"],data_30["across_corr"],data_40["across_corr"],data_50["across_corr"]]
all_data_within = [data_1["within_corr"],data_2["within_corr"],data_3["within_corr"],data_4["within_corr"],data_5["within_corr"],data_10["within_corr"],
                   data_20["within_corr"],data_30["within_corr"],data_40["within_corr"],data_50["within_corr"]]

# %%
all_locs_acorss = [data_1["across_locs"],data_2["across_locs"],data_3["across_locs"],data_4["across_locs"],data_5["across_locs"],data_10["across_locs"],
                   data_20["across_locs"],data_30["across_locs"],data_40["across_locs"],data_50["across_locs"]]
all_locs_within = [data_1["within_locs"],data_2["within_locs"],data_3["within_locs"],data_4["within_locs"],data_5["within_locs"],data_10["within_locs"],
                   data_20["within_locs"],data_30["within_locs"],data_40["within_locs"],data_50["within_locs"]]

# %%
filter = .95
all_across_noone = []
mean_across_noone = []
median_across_noone = []
std_across_noone = []
var_across_noone = []
all_within_noone = []
mean_within_noone = []
median_within_noone = []
std_within_noone = []
var_within_noone = []

# %%
for i in range(len(all_data_across)):
    all_across_noone.append(all_data_across[i][all_data_across[i]<=filter])
    mean_across_noone.append(np.mean(all_across_noone[i]))
    median_across_noone.append(np.median(all_across_noone[i]))
    std_across_noone.append(np.std(all_across_noone[i]))
    var_across_noone.append(np.var(all_across_noone[i]))

    all_within_noone.append(all_data_within[i][all_data_within[i]<=filter])
    mean_within_noone.append(np.mean(all_within_noone[i]))
    median_within_noone.append(np.median(all_within_noone[i]))
    std_within_noone.append(np.std(all_within_noone[i]))
    var_within_noone.append(np.var(all_within_noone[i]))

# %%
lambdas = np.array([1,2,3,4,5,10,20,30,40,50])

fig, axes = plt.subplots(2, 5, figsize=(23, 12), 
                         gridspec_kw={'height_ratios': [1, 1]})

# Flatten axes for easier indexing
axes_flat = axes.flatten()


# Get list of axes to use
use_axes = [axes_flat[0], axes_flat[1], axes_flat[2], axes_flat[3], 
            axes_flat[4],axes_flat[5],axes_flat[6],axes_flat[7],axes_flat[8],axes_flat[9]]

# Plot on each axis
count = 0
for i, ax in enumerate(use_axes):
    ax.hist(all_data_within[count],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {means_within[count]:.3f}, σ = {std_within[count]:.3f}, σ² = {var_within[count]:.3f})")
    ax.axvline(median_within[count], color="grey", linestyle="--", linewidth=2, label=f"Within Median = {median_within[count]:.3f}")
    ax.hist(all_data_across[count],bins=200,density=True,color="black",alpha=0.7,label=f"Across (μ = {means_across[count]:.3f}, σ = {std_across[count]:.3f}, σ² = {var_across[count]:.3f})")
    ax.axvline(median_across[count], color="black", linestyle="--", linewidth=2, label=f"Across Median = {median_across[count]:.3f}")
    ax.set_xlabel("Correlation")
    ax.set_ylabel("Electrode Density")
    ax.set_title(f"Electrode Reconstruction Correlation(Lambda = {lambdas[count]})")
    ax.legend()
    ax.grid()
    count +=1

plt.tight_layout()
plt.show()

# %%
lambdas = np.array([1,2,3,4,5,10,20,30,40,50])

fig, axes = plt.subplots(2, 5, figsize=(23, 12), 
                         gridspec_kw={'height_ratios': [1, 1]})

# Flatten axes for easier indexing
axes_flat = axes.flatten()


# Get list of axes to use
use_axes = [axes_flat[0], axes_flat[1], axes_flat[2], axes_flat[3], 
            axes_flat[4],axes_flat[5],axes_flat[6],axes_flat[7],axes_flat[8],axes_flat[9]]

# Plot on each axis
count = 0
for i, ax in enumerate(use_axes):
    ax.hist(all_within_noone[count],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {mean_within_noone[count]:.3f}, σ = {std_within_noone[count]:.3f}, σ² = {var_within_noone[count]:.3f})")
    ax.axvline(median_within_noone[count], color="grey", linestyle="--", linewidth=2, label=f"Within Median = {median_within_noone[count]:.3f}")
    ax.hist(all_across_noone[count],bins=200,density=True,color="black",alpha=0.7,label=f"Across (μ = {mean_across_noone[count]:.3f}, σ = {std_across_noone[count]:.3f}, σ² = {var_across_noone[count]:.3f})")
    ax.axvline(median_across_noone[count], color="black", linestyle="--", linewidth=2, label=f"Across Median = {median_across_noone[count]:.3f}")
    ax.set_xlabel("Correlation")
    ax.set_ylabel("Electrode Density")
    ax.set_title(f"Electrode Reconstruction Correlation(Lambda = {lambdas[count]})")
    ax.legend()
    ax.grid()
    count +=1

plt.tight_layout()
plt.show()

# %%
'''lambdas = np.array([10,20,30])
fig, ax = plt.subplots(1,3, figsize=(20,6))

for i in range(len(lambdas)):
    axes = ax[i]
    axes.hist(all_data_across[i],bins=200,density=True,color="black",alpha=0.7,label=f"Across (μ = {means_across_run1[i]:.3f}, σ = {std_across_run1[i]:.3f}, σ² = {var_across_run1[i]:.3f})")
    axes.axvline(means_across_run1[i], color="black", linestyle="--", linewidth=2)
    axes.hist(all_data_within[i],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {means_within_run1[i]:.3f}, σ = {std_within_run1[i]:.3f}, σ² = {var_within_run1[i]:.3f})")
    axes.axvline(means_within_run1[i], color="grey", linestyle="--", linewidth=2)
    axes.set_xlabel("Correlation")
    axes.set_ylabel("Electrode Density")
    axes.set_title(f"Electrode Reconstruction Correlation(Lambda = {lambdas[i]})")
    axes.legend()
    axes.grid()

plt.tight_layout()'''
# Out:
# 'lambdas = np.array([10,20,30])\nfig, ax = plt.subplots(1,3, figsize=(20,6))\n\nfor i in range(len(lambdas)):\n    axes = ax[i]\n    axes.hist(all_data_across[i],bins=200,density=True,color="black",alpha=0.7,label=f"Across (μ = {means_across_run1[i]:.3f}, σ = {std_across_run1[i]:.3f}, σ² = {var_across_run1[i]:.3f})")\n    axes.axvline(means_across_run1[i], color="black", linestyle="--", linewidth=2)\n    axes.hist(all_data_within[i],bins=200,density=True,color="grey",alpha=0.7,label=f"Within (μ = {means_within_run1[i]:.3f}, σ = {std_within_run1[i]:.3f}, σ² = {var_within_run1[i]:.3f})")\n    axes.axvline(means_within_run1[i], color="grey", linestyle="--", linewidth=2)\n    axes.set_xlabel("Correlation")\n    axes.set_ylabel("Electrode Density")\n    axes.set_title(f"Electrode Reconstruction Correlation(Lambda = {lambdas[i]})")\n    axes.legend()\n    axes.grid()\n\nplt.tight_layout()'
# notebook controller is DISPOSED.
#
# ...

# %%
# check all recon freq nums (number of data points)
x_freq = np.linspace(1,len(all_data_across),len(all_data_across))
freq_across = []
freq_within = []
for i in range(len(all_data_across)):
    freq_across.append(len(all_data_across[i]))
    freq_within.append(len(all_data_within[i]))


fig,ax = plt.subplots(1)

ax.scatter(x_freq,freq_across,label="Across",color="black")
ax.scatter(x_freq,freq_within,label="Within",color="grey")
ax.set_title("Frequency of Datapoints per Run")
ax.set_xlabel("Run Number")
ax.set_ylabel("Frequency of Datapoints")
ax.grid()
ax.legend()

# %%
lambdas1 = np.array([1,2,3,4,5])
lambdas2 = np.array([10,20,30,40,50])

fig,ax = plt.subplots(2,figsize=(12,8))

ax[0].boxplot(all_data_across[:5],positions=lambdas1,widths=.16,label="Across", patch_artist=True, 
           boxprops=dict(facecolor='black', alpha=0.6),
           medianprops=dict(color="red", linewidth=1))
ax[0].boxplot(all_data_within[:5],positions=lambdas1+.16, widths=.16,label="Within", patch_artist=True,
            boxprops=dict(facecolor='grey', alpha=0.6),
            medianprops=dict(color="red", linewidth=1))
ax[0].set_title("Distribution of Electrode Reconstruction Correlation vs Radius Width")
ax[0].set_xlabel("Radius Width")
ax[0].set_ylabel("Correlation")
ax[0].set_xticks(lambdas1)
ax[0].grid()
ax[0].legend()

ax[1].boxplot(all_data_across[5:],positions=lambdas2,widths=1.4,label="Across", patch_artist=True, 
           boxprops=dict(facecolor='black', alpha=0.6),
           medianprops=dict(color="red", linewidth=1))
ax[1].boxplot(all_data_within[5:],positions=lambdas2+1.4, widths=1.4,label="Within", patch_artist=True,
            boxprops=dict(facecolor='grey', alpha=0.6),
            medianprops=dict(color="red", linewidth=1))
ax[1].set_title("Distribution of Electrode Reconstruction Correlation vs Radius Width")
ax[1].set_xlabel("Radius Width")
ax[1].set_ylabel("Correlation")
ax[1].set_xticks(lambdas2)
ax[1].grid()
ax[1].legend()


plt.tight_layout()

# %%
across_filter_index = []
within_filter_index = []

for i in range(len(all_data_within)):
    across_filter_index.append(np.where(all_data_across[i] >= filter))
    within_filter_index.append(np.where(all_data_within[i] >= filter))

# %%
locs_filter_across = []
locs_filter_within = []

# %%
for i in range(len(all_data_across)):
    locs_filter_across.append(all_locs_acorss[i][across_filter_index[i]])
    locs_filter_within.append(all_locs_within[i][within_filter_index[i]])

# %%
counter = 0
for i in range(2):
    for j in range(5):
        quick_plot(locs_filter_across[counter])
        counter+=1

# %%
test_data = np.load("/mnt/beegfs/projects/jc158347/supereeg_jcs/test_code/data_test.npy")
test_locs = np.load("/mnt/beegfs/projects/jc158347/supereeg_jcs/test_code/locs_test.npy")

# %%
plot.interp_corr(test_data,test_locs,width=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot.interp_corr(test_data,test_locs,width=1)
#
# File /mnt/beegfs/projects/jc158347/supereeg_jcs/test_code/plot.py:463, in interp_corr(locs, corrs, width, vox_size, outfile, save_nii)
#     461 def interp_corr(locs, corrs, width=10, vox_size=10, outfile=None, save_nii=None):
#     462     nii = se.load('std', vox_size=vox_size)
# --> 463     full_locs = nii.get_locs().values
#     464     W = np.exp(_log_rbf(full_locs, locs, width=width))
#     465     interp_corrs =  np.dot(corrs, W.T)
#
# File ~/.conda/envs/supereeg_env/lib/python3.13/site-packages/supereeg/nifti.py:255, in Nifti.get_locs(self)
#     251 """
#     252 Return locations of voxels
#     253 """
#     254 bo = Brain(self)
# --> 255 return bo.get_locs()
#
# ...
